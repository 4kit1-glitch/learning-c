# %%
from jupyturtle import make_turtle, forward, left

def initialize_draw_board():
    wdth = int(input("enter the board width"))
    lenght = int(input("enter the board lenght"))
    draw_speed
    make_turtle(width = wdth, height = lenght, delay = draw_speed):
    
def square(lenght):
    ANGLE = 90
    for _ in range(4):
        forward(lenght)
        left(ANGLE)
square(80)
# Out:
# <svg width="250" height="250" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 125,125 205,125 205,45 125,45 125,125 275,125 275,-25 125,-25 125,125 275,125 275,-25 125,-25 125,125 215,125 215,35 125,35 125,125 235,125 235,15 125,15 125,125" />'
#
# <g transform="rotate(-90.0,125.0,125.0) translate(125.0, 125.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>
